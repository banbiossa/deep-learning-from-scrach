# %% [markdown]
# # 1.3_ss_chap06_hyperparameter_optimization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
from src import utils
import itertools
import logging
import numpy as np
import matplotlib.pylab as plt
import matplotlib.patches as patches
from collections import OrderedDict
# %matplotlib inline

# %%
log_fmt = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
logging.basicConfig(level=logging.INFO, format=log_fmt)
# logging.basicConfig(level=logging.DEBUG, format=log_fmt)
logger = logging.getLogger()

# %%
from src.ch06.hyperparameter_optimization import main

# %% [markdown]
# # Kick

# %%
main()
# Out:
# val acc:0.09 | lr:0.00034332621107889484, weight decay:1.1536063375403232e-08
# val acc:0.7 | lr:0.0051726557410649325, weight decay:5.931864085780057e-08
# val acc:0.11 | lr:0.0003432557332353461, weight decay:1.2698121088384114e-05
# val acc:0.08 | lr:1.9367230478653394e-05, weight decay:4.861551267470594e-08
# val acc:0.08 | lr:5.428967071802179e-05, weight decay:2.599786581807107e-05
# val acc:0.64 | lr:0.006354824747444978, weight decay:2.4518844953723588e-05
# val acc:0.61 | lr:0.004596553626509522, weight decay:2.2812452525099845e-05
# val acc:0.06 | lr:0.00011757489080552414, weight decay:1.7708858371111654e-05
# val acc:0.32 | lr:0.0017298091058645547, weight decay:2.3052006708379294e-05
# val acc:0.11 | lr:2.2804869734843484e-06, weight decay:5.965827500465581e-06
# val acc:0.36 | lr:0.0022833615890616894, weight decay:3.166108554196707e-06
# val acc:0.33 | lr:0.0016935939351622167, weight decay:4.866173787542852e-07
# val acc:0.14 | lr:0.0012552267987064518, weight decay:6.713804035185764e-07
# val acc:0.72 | lr:0.006152200430540962, weight decay:1.2225392041069945e-08
# val acc:0.13 | lr:0.00019205264736906592, weight decay:7.145403863258802e-05
# val acc:0.09 | lr:1.6059195033296407e-06, weight decay:5.826883000277247e-08
# val acc:0.14 | lr:7.596288123103182e-05, weight decay:7.155349836305366e-06
# val acc:0.06 | lr:4.7241121621557894e-05, weight decay:2.6902886863260443e-05
# val acc:0.22 | lr:0.001009638521413181, weight decay:2.7089769422469467e-08
# val acc:0.1 | lr:2.65118413284751e-06, weight decay:8.456185751015657e-06
# val acc:0.13 | lr:0.0008315416367536716, weight decay:8.589760579140903e-06
# val acc:0.11 | lr:1.1039796348264453e-06, weight decay:5.993060382518063e-05
# val acc:0.13 | lr:5.291252002171202e-06, weight decay:1.955362476234549e-06
# val acc:0.02 | lr:6.127952651820075e-05, weight decay:3.875990296223899e-08
# val acc:0.06 | lr:3.975028440890747e-05, weight decay:3.937781721154543e-07
# val acc:0.06 | lr:2.300962700679085e-05, weight decay:1.4281085458620217e-07
# val acc:0.11 | lr:3.704258853069381e-06, weight decay:7.026279035742022e-07
# val acc:0.04 | lr:9.20267219922242e-05, weight decay:2.7155307092686085e-06
# val acc:0.18 | lr:0.00019288310700347032, weight decay:1.2449533580509665e-08
# val acc:0.16 | lr:5.253385690264831e-05, weight decay:1.338959130365142e-06
# val acc:0.43 | lr:0.002265154462660196, weight decay:7.86326120332067e-05
# val acc:0.12 | lr:0.00017193409490503527, weight decay:2.944782155909631e-05
# val acc:0.1 | lr:2.1297699485002482e-05, weight decay:3.8221516399179226e-08
# val acc:0.06 | lr:1.0630412350039196e-05, weight decay:1.2486838937717283e-05
# val acc:0.06 | lr:8.389443851387663e-06, weight decay:8.532462175026992e-08
# val acc:0.44 | lr:0.002774502581425876, weight decay:1.5062419874072833e-05
# val acc:0.81 | lr:0.00825997902451637, weight decay:1.834137135170511e-08
# val acc:0.28 | lr:0.0006259383401378649, weight decay:2.8652635233227976e-08
# val acc:0.1 | lr:1.0807289464203366e-06, weight decay:5.347395502008414e-06
# val acc:0.13 | lr:0.00015508697656605664, weight decay:1.4803079179875754e-08
# val acc:0.07 | lr:0.0002817980644623151, weight decay:1.359993619783867e-08
# val acc:0.07 | lr:5.7532311996478583e-05, weight decay:3.9460018887292e-08
# val acc:0.18 | lr:0.0006683036844898911, weight decay:4.1656029247061465e-07
# val acc:0.08 | lr:1.6163909191876124e-06, weight decay:2.4534867584732835e-08
# val acc:0.05 | lr:1.864079691037569e-06, weight decay:3.9735435708422406e-07
# val acc:0.62 | lr:0.004582220448984601, weight decay:1.307395293060014e-05
# val acc:0.42 | lr:0.0016861398041978833, weight decay:2.815227182293148e-06
# val acc:0.04 | lr:5.29934959207002e-06, weight decay:7.36053412832867e-08
# val acc:0.07 | lr:3.536897512429345e-05, weight decay:3.517021404975222e-05
# val acc:0.1 | lr:0.0003178998570332995, weight decay:1.199359189441875e-06
# val acc:0.07 | lr:0.0005858219401062105, weight decay:2.910991965163646e-05
# val acc:0.05 | lr:0.0005581935170750379, weight decay:8.17934105173368e-06
# val acc:0.09 | lr:1.9966716388531276e-05, weight decay:4.1767899135300973e-07
# val acc:0.37 | lr:0.0026186627143290554, weight decay:4.336340941486251e-05
# val acc:0.04 | lr:0.00010835845196635741, weight decay:1.687039379018857e-05
# val acc:0.15 | lr:8.630861799007361e-05, weight decay:1.1158102139925389e-06
# val acc:0.14 | lr:5.84252704644222e-06, weight decay:2.6267027966085615e-05
# val acc:0.13 | lr:0.0004191984980582922, weight decay:7.68736589894117e-08
# val acc:0.6 | lr:0.00435575674653511, weight decay:1.5135989330186826e-05
# val acc:0.15 | lr:5.1258914045959204e-05, weight decay:3.999252077141123e-05
# val acc:0.76 | lr:0.005983928000610992, weight decay:1.2179089235608623e-05
# val acc:0.11 | lr:3.0925771156871376e-06, weight decay:5.494965624982302e-07
# val acc:0.06 | lr:0.00013000935837892627, weight decay:5.245531653862726e-05
# val acc:0.42 | lr:0.002060516803994585, weight decay:6.797321586339543e-05
# val acc:0.07 | lr:0.0002639539752151846, weight decay:1.7369839633579322e-08
# val acc:0.11 | lr:7.123077975733782e-05, weight decay:7.556288171998153e-08
# val acc:0.07 | lr:0.0007137209873380748, weight decay:1.0438116916682084e-08
# val acc:0.08 | lr:2.4780817648216283e-06, weight decay:4.625947049868451e-07
# val acc:0.08 | lr:2.4187425800165876e-05, weight decay:1.0609817990372024e-06
# val acc:0.08 | lr:2.860185736112342e-06, weight decay:7.52708848685056e-06
# val acc:0.08 | lr:1.4648908355749751e-06, weight decay:5.643648453502579e-07
# val acc:0.28 | lr:0.0007432494153681257, weight decay:9.870977657221596e-08
# val acc:0.13 | lr:1.1604286613167743e-06, weight decay:1.7520862788179817e-05
# val acc:0.09 | lr:6.0018091541467806e-05, weight decay:3.724138480553348e-08
# val acc:0.09 | lr:1.0265230940753272e-06, weight decay:2.9747609686353772e-08
# val acc:0.38 | lr:0.0024018745533120347, weight decay:2.3133710623006565e-07
# val acc:0.09 | lr:1.2311090465702962e-05, weight decay:4.745760036616215e-07
# val acc:0.12 | lr:0.001519042659360838, weight decay:1.7407920844170418e-05
# val acc:0.81 | lr:0.009659826078736666, weight decay:8.32929797149603e-08
# val acc:0.15 | lr:1.8728030019579678e-05, weight decay:1.0550892706661085e-07
# val acc:0.32 | lr:0.001503354736921752, weight decay:3.496831325633084e-07
# val acc:0.12 | lr:0.00024068597092784323, weight decay:4.039723323860067e-08
# val acc:0.1 | lr:0.00041139992906510464, weight decay:2.802754141071596e-06
# val acc:0.1 | lr:5.1465890437606356e-05, weight decay:5.935813986396246e-06
# val acc:0.12 | lr:3.103059665326574e-05, weight decay:7.986037657792881e-08
# val acc:0.11 | lr:3.7469734056456355e-06, weight decay:2.3809629789797396e-06
# val acc:0.08 | lr:0.00017988053468594216, weight decay:9.8960447164793e-07
# val acc:0.04 | lr:0.00013239410242020763, weight decay:2.166865820513837e-07
# val acc:0.16 | lr:0.0008852293705421415, weight decay:9.618146489986788e-05
# val acc:0.17 | lr:0.00027782892031034023, weight decay:4.185090099707777e-05
# val acc:0.75 | lr:0.0065645400411606745, weight decay:1.600110660206135e-06
# val acc:0.16 | lr:0.0007463755286522228, weight decay:2.907846519224332e-08
# val acc:0.11 | lr:1.5191001163276929e-05, weight decay:6.52468405940349e-07
# val acc:0.22 | lr:0.001223384299083013, weight decay:2.0679410280628523e-07
# val acc:0.24 | lr:0.0010029612700829219, weight decay:2.2977778337016922e-05
# val acc:0.14 | lr:3.851141443085548e-06, weight decay:5.667286854244946e-07
# val acc:0.1 | lr:1.2728543768372658e-06, weight decay:1.7285240390380415e-08
# val acc:0.15 | lr:0.000442100690940006, weight decay:1.1523091188887924e-07
# val acc:0.21 | lr:0.00034152515295220816, weight decay:6.731196150425625e-08
# val acc:0.08 | lr:1.9129681160747203e-06, weight decay:5.6584555609911864e-08
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.81) | lr:0.00825997902451637, weight decay:1.834137135170511e-08
# Best-2(val acc:0.81) | lr:0.009659826078736666, weight decay:8.32929797149603e-08
# Best-3(val acc:0.76) | lr:0.005983928000610992, weight decay:1.2179089235608623e-05
# Best-4(val acc:0.75) | lr:0.0065645400411606745, weight decay:1.600110660206135e-06
# Best-5(val acc:0.72) | lr:0.006152200430540962, weight decay:1.2225392041069945e-08
# Best-6(val acc:0.7) | lr:0.0051726557410649325, weight decay:5.931864085780057e-08
# Best-7(val acc:0.64) | lr:0.006354824747444978, weight decay:2.4518844953723588e-05
# Best-8(val acc:0.62) | lr:0.004582220448984601, weight decay:1.307395293060014e-05
# Best-9(val acc:0.61) | lr:0.004596553626509522, weight decay:2.2812452525099845e-05
# Best-10(val acc:0.6) | lr:0.00435575674653511, weight decay:1.5135989330186826e-05
# Best-11(val acc:0.44) | lr:0.002774502581425876, weight decay:1.5062419874072833e-05
# Best-12(val acc:0.43) | lr:0.002265154462660196, weight decay:7.86326120332067e-05
# Best-13(val acc:0.42) | lr:0.0016861398041978833, weight decay:2.815227182293148e-06
# Best-14(val acc:0.42) | lr:0.002060516803994585, weight decay:6.797321586339543e-05
# Best-15(val acc:0.38) | lr:0.0024018745533120347, weight decay:2.3133710623006565e-07
# Best-16(val acc:0.37) | lr:0.0026186627143290554, weight decay:4.336340941486251e-05
# Best-17(val acc:0.36) | lr:0.0022833615890616894, weight decay:3.166108554196707e-06
# Best-18(val acc:0.33) | lr:0.0016935939351622167, weight decay:4.866173787542852e-07
# Best-19(val acc:0.32) | lr:0.0017298091058645547, weight decay:2.3052006708379294e-05
# Best-20(val acc:0.32) | lr:0.001503354736921752, weight decay:3.496831325633084e-07
